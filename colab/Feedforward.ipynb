# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Feedforward(nn.Module):
  def __init__(self, embd_dim):
    super().__init__()
    self.layers = nn.Sequential(
        nn.Linear(embd_dim, 4*embd_dim),
        nn.GELU(),
        nn.Linear(4*embd_dim, embd_dim),
    )

  def forward(self,x):
    return self.layers(x)

# %%
lin  = nn.Sequential(nn.Linear(4, 4*4), GELU(), nn.Linear(4*4,4))

# %%
input = torch.rand(2,3,6)
embd_dim = 6
ffn = Feedforward(embd_dim=6)
ffn(input).shape
# Out:
# torch.Size([2, 3, 6])

# %%
print(ffn.layers[0].weight.shape)
print(ffn.layers[2].weight.shape)
# Out:
# torch.Size([24, 6])
# torch.Size([6, 24])
